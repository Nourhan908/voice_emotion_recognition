# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
pip install librosa soundfile scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: librosa in c:\users\ram\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: soundfile in c:\users\ram\anaconda3\lib\site-packages (0.13.1)
# Requirement already satisfied: scikit-learn in c:\users\ram\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: matplotlib in c:\users\ram\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\ram\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\ram\anaconda3\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\ram\anaconda3\lib\site-packages (from librosa) (0.60.0)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\ram\anaconda3\lib\site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ram\anaconda3\lib\site-packages (from librosa) (1.13.1)
# Requirement already satisfied: joblib>=1.0 in c:\users\ram\anaconda3\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\ram\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\ram\anaconda3\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\ram\anaconda3\lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\ram\anaconda3\lib\site-packages (from librosa) (4.11.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\ram\anaconda3\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\ram\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: cffi>=1.0 in c:\users\ram\anaconda3\lib\site-packages (from soundfile) (1.17.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ram\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ram\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ram\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ram\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ram\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ram\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ram\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ram\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ram\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ram\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pycparser in c:\users\ram\anaconda3\lib\site-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\ram\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ram\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ram\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\ram\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\ram\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: six>=1.5 in c:\users\ram\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ram\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ram\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ram\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ram\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import glob
import pandas as pd

# Step 1: Set the path to your extracted RAVDESS folder
root_dir = root_dir = "C:\\Users\\Ram\\Documents\\SAMRT\\smart_dataset"
 # <- change this to your real path

# Step 2: Recursively get all .wav files in all folders
wav_files = glob.glob(os.path.join(root_dir, "**", "*.wav"), recursive=True)

print(f"Found {len(wav_files)} .wav files")

# Step 3: Define emotion label map based on RAVDESS naming convention
emotion_map = {
    "01": "neutral",
    "02": "calm",
    "03": "happy",
    "04": "sad",
    "05": "angry",
    "06": "fearful",
    "07": "disgust",
    "08": "surprised"
}

# Step 4: Create a DataFrame with paths and emotion labels
data = []
for fpath in wav_files:
    filename = os.path.basename(fpath)
    parts = filename.split("-")
    emotion_code = parts[2]
    emotion_label = emotion_map.get(emotion_code, "unknown")
    data.append({"file_path": fpath, "emotion": emotion_label})

df = pd.DataFrame(data)

# Step 5: Preview the DataFrame
df.head()
# Out:
# Found 2880 .wav files
#                                            file_path  emotion
# 0  C:\Users\Ram\Documents\SAMRT\smart_dataset\Act...  neutral
# 1  C:\Users\Ram\Documents\SAMRT\smart_dataset\Act...  neutral
# 2  C:\Users\Ram\Documents\SAMRT\smart_dataset\Act...  neutral
# 3  C:\Users\Ram\Documents\SAMRT\smart_dataset\Act...  neutral
# 4  C:\Users\Ram\Documents\SAMRT\smart_dataset\Act...     calm

# %%
import librosa
import numpy as np
from tqdm import tqdm

# Function to extract MFCC, Chroma, and Mel features
def extract_features(file_path):
    try:
        # Load audio file
        y, sr = librosa.load(file_path, duration=3, offset=0.5)  # Load first 3s, skip 0.5s
        # MFCCs
        mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
        # Chroma
        chroma = np.mean(librosa.feature.chroma_stft(y=y, sr=sr).T, axis=0)
        # Mel Spectrogram
        mel = np.mean(librosa.feature.melspectrogram(y=y, sr=sr).T, axis=0)
        # Combine all
        return np.hstack([mfcc, chroma, mel])
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None

# %%
# Create X (features) and y (labels)
X, y = [], []

# Use tqdm to show progress bar
for i, row in tqdm(df.iterrows(), total=len(df)):
    features = extract_features(row["file_path"])
    if features is not None:
        X.append(features)
        y.append(row["emotion"])
# Out:
#   0%|                                                                                         | 0/2880 [00:00<?, ?it/s]C:\Users\Ram\anaconda3\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# C:\Users\Ram\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# C:\Users\Ram\anaconda3\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,
# 100%|██████████████████████████████████████████████████████████████████████████████| 2880/2880 [02:13<00:00, 21.62it/s]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

# %%
# Convert labels to numeric format
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('smote', SMOTE()),
    ('svc', SVC())
])

# %%
params = {
    'svc__C': [0.1, 1, 10],
    'svc__gamma': ['scale', 0.01, 0.001],
    'svc__kernel': ['rbf']
}

# %%
grid = GridSearchCV(pipeline, param_grid=params, cv=5, scoring='accuracy', verbose=1, n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('smote', SMOTE()), ('svc', SVC())]),
#              n_jobs=-1,
#              param_grid={'svc__C': [0.1, 1, 10],
#                          'svc__gamma': ['scale', 0.01, 0.001],
#                          'svc__kernel': ['rbf']},
#              scoring='accuracy', verbose=1)

# %%
best_model = grid.best_estimator_
print("Best Parameters:", grid.best_params_)
# Out:
# Best Parameters: {'svc__C': 10, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}

# %%
X_test_scaled = best_model.named_steps['scaler'].transform(X_test)

# %%
y_pred = best_model.named_steps['svc'].predict(X_test_scaled)

# %%
print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Test Accuracy: 0.9375
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.94      0.92      0.93        79
#         calm       0.91      1.00      0.95        69
#      disgust       0.99      0.92      0.95        84
#      fearful       0.94      0.96      0.95        80
#        happy       0.93      0.94      0.93        82
#      neutral       0.91      0.95      0.93        42
#          sad       0.93      0.89      0.91        61
#    surprised       0.95      0.92      0.94        79
#
#     accuracy                           0.94       576
#    macro avg       0.94      0.94      0.94       576
# weighted avg       0.94      0.94      0.94       576

# %%
def predict_emotion(file_path, model, label_encoder):
    features = extract_features(file_path)
    if features is None:
        return "Error extracting features"
    features = features.reshape(1, -1)  # Reshape for sklearn
    prediction = model.predict(features)
    predicted_emotion = label_encoder.inverse_transform(prediction)
    return predicted_emotion[0]

# %%
test_file = r"C:\Users\Ram\Downloads\Compressed\OAF_angry\OAF_base_angry.wav"
predicted_emotion = predict_emotion(test_file,best_model, le)
print(f"Predicted emotion: {predicted_emotion}")
# Out:
# Predicted emotion: angry

# %%
test_file = r"C:\Users\Ram\Downloads\Compressed\OAF_Sad\OAF_book_sad.wav"
print("File exists:", os.path.exists(test_file))

predicted_emotion = predict_emotion(test_file, best_model, le)
print(f"Predicted emotion: {predicted_emotion}")
# Out:
# File exists: True
# Predicted emotion: sad

# %%
test_file = r""
print("File exists:", os.path.exists(test_file))

predicted_emotion = predict_emotion(test_file, best_model, le)
print(f"Predicted emotion: {predicted_emotion}")
# Out:
# File exists: True
# Predicted emotion: sad
